# %% [markdown]
# ## Objective: Model sediment erosion and deposition from fluvial processes

# %% [markdown]
# #### Inputs: Eightmile Lake, AK DEM at 2m / px resolution
# #### Components: Space, FlowAccumulator, DepressionFinderAndRouter, FastscapeEroder
# #### Outputs: sediment flux

# %%
import numpy as np
import matplotlib.pyplot as plt

import rasterio as rio

from landlab import RasterModelGrid
from landlab.plot import imshow_grid
from landlab.components import Space, FlowAccumulator, DepressionFinderAndRouter, FastscapeEroder
# Out:
# /home/egp/.virtualenvs/landlab/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# ## 1) Import and downsample DEM

# %%
current = 2 # meters per pixel
target = 30 # meters per pixel
scale = current / target

with rio.open('./gis/projects/dem/eightmile-lake-watershed-dem-filled.tif') as src:

    # resample data to target shape
    data = src.read(
        out_shape = (
            src.count,
            int(src.height * scale),
            int(src.width * scale)
        ),
        resampling = rio.enums.Resampling.bilinear
    )

    # scale image transform
    transform = src.transform * src.transform.scale(
        (src.width / data.shape[-1]),
        (src.height / data.shape[-2])
    )

# %%
dem = np.flip(np.transpose(data[0]), 0)

plt.imshow(dem, cmap = 'terrain')
plt.scatter(210, 540, s = 25, color = 'red')
plt.show()

# %% [markdown]
# ## 2) Set initial and boundary conditions

# %%
grid = RasterModelGrid([dem.shape[0], dem.shape[1]], target)

# %%
grid.add_field('topographic__elevation', np.flip(dem.astype(float), 0), at = 'node', clobber = True, copy = True)
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
grid.set_nodata_nodes_to_closed(grid.at_node['topographic__elevation'], 0)
grid.set_closed_boundaries_at_grid_edges(
    bottom_is_closed = True,
    top_is_closed = True,
    right_is_closed = True,
    left_is_closed = True
)

# %%
outlet_id = grid.set_watershed_boundary_condition('topographic__elevation', nodata_value = 0, return_outlet_id = True,
                                                  remove_disconnected = True, adjacency_method = 'D8')

# %%
outlet_coords = (grid.node_x[outlet_id], grid.node_y[outlet_id])

# %%
fig, ax = plt.subplots(figsize = (10, 10))
imshow_grid(grid, 'topographic__elevation')
plt.scatter(outlet_coords[0], outlet_coords[1], color = 'aquamarine', s = 50, facecolors = 'none', label = 'Modeled watershed outlet')
plt.scatter(6300, 19440, s = 50, color = 'purple', facecolors = 'none', label = 'Eightmile Lake (appx.)')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ## 3) Burn a stream network using Fastscape

# %%
fast_dt = 100
FA = FlowAccumulator(grid, flow_director = 'D8')
DF = DepressionFinderAndRouter(grid)
FE = FastscapeEroder(grid, K_sp = 0.001, m_sp = 0.5, n_sp = 1)

# %%
nt = 25

for t in range(nt):
    FA.run_one_step()
    DF.map_depressions()
    FE.run_one_step(dt = fast_dt)
    
    if (t + 1) % 5 == 0:
        print('Completed ' + str(t + 1) + ' time steps.')
# Out:
# Completed 5 time steps.
# Completed 10 time steps.
# Completed 15 time steps.
# Completed 20 time steps.
# Completed 25 time steps.

# %%
fig, ax = plt.subplots(figsize = (10, 10))
imshow_grid(grid, 'topographic__elevation', cmap = 'pink')
plt.scatter(outlet_coords[0], outlet_coords[1], color = 'aquamarine', s = 50, facecolors = 'none', label = 'Modeled watershed outlet')
plt.scatter(6300, 19440, s = 50, color = 'purple', facecolors = 'none', label = 'Eightmile Lake (appx.)')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ## 4) Initialize components

# %%
grid.add_zeros('soil__depth', at = 'node', clobber = True)
grid.at_node['soil__depth'] += 0.5
grid.at_node['topographic__elevation'] += grid.at_node['soil__depth']

# %%
SP = Space(
    grid,
    K_sed = 1e-5,
    K_br = 1e-11,
    F_f = 0.5,
    phi = 0.1,
    H_star = 1.,
    v_s = 1e-3,
    m_sp = 0.5,
    n_sp = 1.0,
    sp_crit_sed = 0,
    sp_crit_br = 0
)

# %%
nt = 10
space_dt = 10
count = 0
initial_topography = grid.at_node['topographic__elevation']

for t in range(nt):
    FA.run_one_step()
    DF.map_depressions()
    SP.run_one_step(dt = space_dt)
    
    count += 1
    if count % 5 == 0:
        print('Completed ' + str(count) + ' time steps.')
# Out:
# Completed 5 time steps.
# Completed 10 time steps.
# Completed 15 time steps.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <module>
#       7 FA.run_one_step()
#       8 DF.map_depressions()
# ----> 9 SP.run_one_step(dt = space_dt)
#      11 count += 1
#      12 if count % 5 == 0:
#
# File ~/.virtualenvs/landlab/lib/python3.9/site-packages/landlab/components/space/space.py:591, in Space.run_one_step_basic(self, dt)
#     582 for idx in self.grid.core_nodes:
#     583     args = (
#     584         self._br_erosion_term[idx],
#     585         1.0 / self._H_star,
#    (...)
#     588         H0[idx],
#     589     )
# --> 591     dR[idx] = quad(_dRdt, 0, dt, args)[0]
#     593 self._bedrock__elevation += dR
#     595 # finally, determine topography by summing bedrock and soil
#
# File ~/.virtualenvs/landlab/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File ~/.virtualenvs/landlab/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File ~/.virtualenvs/landlab/lib/python3.9/site-packages/landlab/components/space/space.py:757, in _dRdt(t, a, b, c, d, H0)
#     755 else:
#     756     term1 = 1.0 / ((c / d) - 1)
# --> 757     term2 = np.exp((c - d) * t * b)
#     758     term3 = (c / d - 1) * np.exp(bH0) + 1
#     759     interior = term1 * (term2 * (term3) - 1)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize = (10, 10))
imshow_grid(grid, 'soil__depth', vmin = 0.2)
plt.scatter(outlet_coords[0], outlet_coords[1], color = 'aquamarine', s = 50, facecolors = 'none', label = 'Modeled watershed outlet')
plt.scatter(6300, 19440, s = 50, color = 'purple', facecolors = 'none', label = 'Eightmile Lake (appx.)')
plt.legend(loc = 'upper right')
plt.show()

# %%
grad_links = grid.calc_grad_at_link('topographic__elevation')
grad_nodes = grid.map_mean_of_links_to_node(grad_links)
concavity_links = grid.calc_grad_at_link(grad_nodes)
concavity_nodes = grid.map_mean_of_links_to_node(concavity_links)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
imshow_grid(grid, concavity_nodes, vmin = -0.1, vmax = 0.1)
plt.scatter(outlet_coords[0], outlet_coords[1], color = 'aquamarine', s = 50, facecolors = 'none', label = 'Modeled watershed outlet')
plt.scatter(6300, 19440, s = 50, color = 'purple', facecolors = 'none', label = 'Eightmile Lake (appx.)')
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.scatter(concavity_nodes[grid.core_nodes], grid.at_node['soil__depth'][grid.core_nodes])
plt.show()
